# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
d=pd.read_excel("Olympic1.xlsx")

# %% [markdown]
# # Print Data set

# %%
d
# Out:
#                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 0           Michael Phelps  23.0  United States  2008            2008-08-24
# 1           Michael Phelps  19.0  United States  2004            2004-08-29
# 2           Michael Phelps  27.0  United States  2012            2012-08-12
# 3         Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4            Aleksey Nemov  24.0         Russia  2000            2000-10-01
# ...                    ...   ...            ...   ...                   ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
# ...

# %% [markdown]
# # To print dimensions of data set

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# # Check data types

# %%
d.dtypes
# Out:
# Athlete                          object
# Age                             float64
# Country                          object
# Year                              int64
# Closing Ceremony Date    datetime64[ns]
# Sport                            object
# Gold Medals                       int64
# Silver Medals                     int64
# Bronze Medals                     int64
# Total Medals                      int64
# dtype: object

# %% [markdown]
# # Size of the dataset

# %%
d.size
# Out:
# 86180

# %% [markdown]
# # To print number of rows and columns

# %%
d.shape
# Out:
# (8618, 10)

# %% [markdown]
# # To chect the index of data set

# %%
d.index
# Out:
# RangeIndex(start=0, stop=8618, step=1)

# %% [markdown]
# # To print information of data set

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Athlete                8613 non-null   object
#  1   Age                    8613 non-null   float64
#  2   Country                8618 non-null   object
#  3   Year                   8618 non-null   int64
#  4   Closing Ceremony Date  8618 non-null   datetime64[ns]
#  5   Sport                  8618 non-null   object
#  6   Gold Medals            8618 non-null   int64
#  7   Silver Medals          8618 non-null   int64
#  8   Bronze Medals          8618 non-null   int64
#  9   Total Medals           8618 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 673.4+ KB

# %% [markdown]
# # To print name of coulmns in data set

# %%
d.columns
# Out:
# Index(['Athlete', 'Age', 'Country', 'Year', 'Closing Ceremony Date', 'Sport',
#        'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'],
#       dtype='object')

# %% [markdown]
# # To print number of unique value in the data set

# %%
d.nunique()
# Out:
# Athlete                  6955
# Age                        42
# Country                   110
# Year                        7
# Closing Ceremony Date       7
# Sport                      49
# Gold Medals                 7
# Silver Medals               4
# Bronze Medals               4
# Total Medals                7
# dtype: int64

# %% [markdown]
# # To print data set in each coulmns

# %%
d["Athlete"]
# Out:
# 0             Michael Phelps
# 1             Michael Phelps
# 2             Michael Phelps
# 3           Natalie Coughlin
# 4              Aleksey Nemov
#                 ...
# 8613        Olena Sadovnycha
# 8614        Kateryna Serdiuk
# 8615        Wietse van Alten
# 8616    Sandra Wagner-Sachse
# 8617               Rod White
# Name: Athlete, Length: 8618, dtype: object

# %%
d["Athlete"].unique()
# Out:
# array(['Michael Phelps', 'Natalie Coughlin', 'Aleksey Nemov', ...,
#        'Wietse van Alten', 'Sandra Wagner-Sachse', 'Rod White'],
#       dtype=object)

# %%
d["Age"]
# Out:
# 0       23.0
# 1       19.0
# 2       27.0
# 3       25.0
# 4       24.0
#         ...
# 8613    32.0
# 8614    17.0
# 8615    21.0
# 8616    31.0
# 8617    23.0
# Name: Age, Length: 8618, dtype: float64

# %%
d["Age"].unique()
# Out:
# array([23., 19., 27., 25., 24., 17., 22., 21., 33., 26., 18., 29., 20.,
#        30., 28., 16., 32., 41., 15., 34., 31., 35., 37., 38., 46., 40.,
#        44., 45., 39., 42., 36., nan, 49., 43., 47., 52., 50., 54., 51.,
#        56., 55., 61., 48.])

# %%
d["Country"]
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4              Russia
#             ...
# 8613          Ukraine
# 8614          Ukraine
# 8615      Netherlands
# 8616          Germany
# 8617    United States
# Name: Country, Length: 8618, dtype: object

# %%
d["Country"].unique()
# Out:
# array(['United States', 'Russia', 'Australia', 'Canada', 'Norway',
#        'China', 'Zimbabwe', 'Netherlands', 'South Korea', 'Croatia',
#        'France', 'Japan', 'Hungary', 'Germany', 'Poland', 'South Africa',
#        'Sweden', 'Ukraine', 'Italy', 'Czech Republic', 'Austria',
#        'Finland', 'Romania', 'Great Britain', 'Jamaica', 'Singapore',
#        'Belarus', 'Chile', 'Spain', 'Tunisia', 'Brazil', 'Slovakia',
#        'Costa Rica', 'Bulgaria', 'Switzerland', 'New Zealand', 'Estonia',
#        'Kenya', 'Ethiopia', 'Trinidad and Tobago', 'Turkey', 'Morocco',
#        'Bahamas', 'Slovenia', 'Armenia', 'Azerbaijan', 'India',
#        'Puerto Rico', 'Egypt', 'Kazakhstan', 'Iran', 'Georgia',
#        'Lithuania', 'Cuba', 'Colombia', 'Mongolia', 'Uzbekistan',
#        'North Korea', 'Tajikistan', 'Kyrgyzstan', 'Greece', 'Macedonia',
#        'Moldova', 'Chinese Taipei', 'Indonesia', 'Thailand', 'Vietnam',
#        'Latvia', 'Venezuela', 'Mexico', 'Nigeria', 'Qatar', 'Serbia',
# ...

# %%
d["Year"]
# Out:
# 0       2008
# 1       2004
# 2       2012
# 3       2008
# 4       2000
#         ...
# 8613    2000
# 8614    2000
# 8615    2000
# 8616    2000
# 8617    2000
# Name: Year, Length: 8618, dtype: int64

# %%
d["Year"].unique()
# Out:
# array([2008, 2004, 2012, 2000, 2006, 2010, 2002], dtype=int64)

# %%
d["Closing Ceremony Date"]
# Out:
# 0      2008-08-24
# 1      2004-08-29
# 2      2012-08-12
# 3      2008-08-24
# 4      2000-10-01
#           ...
# 8613   2000-10-01
# 8614   2000-10-01
# 8615   2000-10-01
# 8616   2000-10-01
# 8617   2000-10-01
# Name: Closing Ceremony Date, Length: 8618, dtype: datetime64[ns]

# %%
d["Closing Ceremony Date"].unique()
# Out:
# array(['2008-08-24T00:00:00.000000000', '2004-08-29T00:00:00.000000000',
#        '2012-08-12T00:00:00.000000000', '2000-10-01T00:00:00.000000000',
#        '2006-02-26T00:00:00.000000000', '2010-02-28T00:00:00.000000000',
#        '2002-02-24T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
d["Sport"]
# Out:
# 0         Swimming
# 1         Swimming
# 2         Swimming
# 3         Swimming
# 4       Gymnastics
#            ...
# 8613       Archery
# 8614       Archery
# 8615       Archery
# 8616       Archery
# 8617       Archery
# Name: Sport, Length: 8618, dtype: object

# %%
d["Sport"].unique()
# Out:
# array(['Swimming', 'Gymnastics', 'Speed Skating', 'Cross Country Skiing',
#        'Short-Track Speed Skating', 'Diving', 'Cycling', 'Biathlon',
#        'Alpine Skiing', 'Ski Jumping', 'Nordic Combined', 'Athletics',
#        'Table Tennis', 'Tennis', 'Synchronized Swimming', 'Shooting',
#        'Rowing', 'Fencing', 'Equestrian', 'Canoeing', 'Bobsleigh',
#        'Badminton', 'Archery', 'Wrestling', 'Weightlifting', 'Waterpolo',
#        'Volleyball', 'Triathlon', 'Trampoline', 'Taekwondo', 'Softball',
#        'Snowboarding', 'Skeleton', 'Sailing', 'Rhythmic Gymnastics',
#        'Modern Pentathlon', 'Luge', 'Judo', 'Ice Hockey', 'Hockey',
#        'Handball', 'Football', 'Figure Skating', 'Freestyle Skiing',
#        'Curling', 'Baseball', 'Boxing', 'Beach Volleyball', 'Basketball'],
#       dtype=object)

# %%
d["Gold Medals"]
# Out:
# 0       8
# 1       6
# 2       4
# 3       1
# 4       2
#        ..
# 8613    0
# 8614    0
# 8615    0
# 8616    0
# 8617    0
# Name: Gold Medals, Length: 8618, dtype: int64

# %%
d["Gold Medals"].unique()
# Out:
# array([8, 6, 4, 1, 2, 3, 0], dtype=int64)

# %%
d["Silver Medals"]
# Out:
# 0       0
# 1       0
# 2       2
# 3       2
# 4       1
#        ..
# 8613    1
# 8614    1
# 8615    0
# 8616    0
# 8617    0
# Name: Silver Medals, Length: 8618, dtype: int64

# %%
d["Silver Medals"].unique()
# Out:
# array([0, 2, 1, 3], dtype=int64)

# %%
d["Bronze Medals"]
# Out:
# 0       0
# 1       2
# 2       0
# 3       3
# 4       3
#        ..
# 8613    0
# 8614    0
# 8615    1
# 8616    1
# 8617    1
# Name: Bronze Medals, Length: 8618, dtype: int64

# %%
d["Bronze Medals"].unique()
# Out:
# array([0, 2, 3, 1], dtype=int64)

# %%
d["Total Medals"]
# Out:
# 0       8
# 1       8
# 2       6
# 3       6
# 4       6
#        ..
# 8613    1
# 8614    1
# 8615    1
# 8616    1
# 8617    1
# Name: Total Medals, Length: 8618, dtype: int64

# %%
d["Total Medals"].unique()
# Out:
# array([8, 6, 5, 4, 3, 2, 1], dtype=int64)

# %% [markdown]
# # Count number of each sports

# %%
d["Sport"].value_counts()
# Out:
# Athletics                    687
# Rowing                       567
# Swimming                     487
# Football                     407
# Hockey                       388
# Ice Hockey                   384
# Handball                     351
# Waterpolo                    306
# Canoeing                     295
# Basketball                   287
# Volleyball                   281
# Cycling                      261
# Wrestling                    245
# Fencing                      230
# Judo                         224
# Baseball                     216
# Sailing                      210
# Gymnastics                   194
# Boxing                       188
# Shooting                     181
# Weightlifting                180
# Equestrian                   157
# Softball                     134
# Cross Country Skiing         128
# Diving                       113
# Taekwondo                    112
# Synchronized Swimming        109
# Speed Skating                103
# ...

# %% [markdown]
# # To print Statistical information

# %%
d.describe()
# Out:
#                Age         Year  Gold Medals  Silver Medals  Bronze Medals  \
# count  8613.000000  8618.000000  8618.000000    8618.000000    8618.000000
# mean     26.405434  2005.978881     0.364702       0.363309       0.377698
# std       5.102118     4.289946     0.545349       0.511613       0.505005
# min      15.000000  2000.000000     0.000000       0.000000       0.000000
# 25%      23.000000  2002.000000     0.000000       0.000000       0.000000
# 50%      26.000000  2006.000000     0.000000       0.000000       0.000000
# 75%      29.000000  2010.000000     1.000000       1.000000       1.000000
# max      61.000000  2012.000000     8.000000       3.000000       3.000000
#
#        Total Medals
# count   8618.000000
# mean       1.105709
# std        0.408892
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        8.000000

# %% [markdown]
# # To print all Staistical information

# %%
d.describe(include="all")
# Out:
#             Athlete          Age        Country         Year  \
# count          8613  8613.000000           8618  8618.000000
# unique         6955          NaN            110          NaN
# top     Ben Ainslie          NaN  United States          NaN
# freq              4          NaN           1109          NaN
# first           NaN          NaN            NaN          NaN
# last            NaN          NaN            NaN          NaN
# mean            NaN    26.405434            NaN  2005.978881
# std             NaN     5.102118            NaN     4.289946
# min             NaN    15.000000            NaN  2000.000000
# 25%             NaN    23.000000            NaN  2002.000000
# 50%             NaN    26.000000            NaN  2006.000000
# 75%             NaN    29.000000            NaN  2010.000000
# max             NaN    61.000000            NaN  2012.000000
#
#        Closing Ceremony Date      Sport  Gold Medals  Silver Medals  \
# ...

# %% [markdown]
# # Print mean, median and mode of data set

# %%
d.mean()
# Out:
# Age                26.405434
# Year             2005.978881
# Gold Medals         0.364702
# Silver Medals       0.363309
# Bronze Medals       0.377698
# Total Medals        1.105709
# dtype: float64

# %%
d.median()
# Out:
# Age                26.0
# Year             2006.0
# Gold Medals         0.0
# Silver Medals       0.0
# Bronze Medals       0.0
# Total Medals        1.0
# dtype: float64

# %%
d.mode()
# Out:
#                     Athlete   Age        Country    Year  \
# 0         Anky van Grunsven  24.0  United States  2008.0
# 1            Artur Taymazov   NaN            NaN     NaN
# 2               Ben Ainslie   NaN            NaN     NaN
# 3           Bradley Wiggins   NaN            NaN     NaN
# 4              Brenda Villa   NaN            NaN     NaN
# 5                 Chris Hoy   NaN            NaN     NaN
# 6   Christie Pearce-Rampone   NaN            NaN     NaN
# 7            Emilie Heymans   NaN            NaN     NaN
# 8            Eskild Ebbesen   NaN            NaN     NaN
# 9             Heather Petri   NaN            NaN     NaN
# 10              Jason Lezak   NaN            NaN     NaN
# 11           Katalin Kovács   NaN            NaN     NaN
# 12       Katherine Grainger   NaN            NaN     NaN
# 13   Katrin Wagner-Augustin   NaN            NaN     NaN
# 14                Kim Rhode   NaN            NaN     NaN
# ...

# %% [markdown]
# # Check wehether any null values in data set

# %%
d.isna()
# Out:
#       Athlete    Age  Country   Year  Closing Ceremony Date  Sport  \
# 0       False  False    False  False                  False  False
# 1       False  False    False  False                  False  False
# 2       False  False    False  False                  False  False
# 3       False  False    False  False                  False  False
# 4       False  False    False  False                  False  False
# ...       ...    ...      ...    ...                    ...    ...
# 8613    False  False    False  False                  False  False
# 8614    False  False    False  False                  False  False
# 8615    False  False    False  False                  False  False
# 8616    False  False    False  False                  False  False
# 8617    False  False    False  False                  False  False
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0           False          False          False         False
# ...

# %% [markdown]
# # Sum of null values

# %%
d.isna().sum()
# Out:
# Athlete                  5
# Age                      5
# Country                  0
# Year                     0
# Closing Ceremony Date    0
# Sport                    0
# Gold Medals              0
# Silver Medals            0
# Bronze Medals            0
# Total Medals             0
# dtype: int64

# %% [markdown]
# # To check duplicated value in the data set

# %%
d.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8613    False
# 8614    False
# 8615    False
# 8616    False
# 8617    False
# Length: 8618, dtype: bool

# %% [markdown]
# # Sum of dupilcated values in the data set

# %%
d.duplicated().sum()
# Out:
# 3

# %% [markdown]
# # Check relationship between data set

# %%
d.corr()
# Out:
#                     Age      Year  Gold Medals  Silver Medals  Bronze Medals  \
# Age            1.000000 -0.006814    -0.029553      -0.011229      -0.015306
# Year          -0.006814  1.000000    -0.002958      -0.000522       0.009467
# Gold Medals   -0.029553 -0.002958     1.000000      -0.348922      -0.402883
# Silver Medals -0.011229 -0.000522    -0.348922       1.000000      -0.445830
# Bronze Medals -0.015306  0.009467    -0.402883      -0.445830       1.000000
# Total Medals  -0.072357  0.007095     0.399562       0.235226       0.139893
#
#                Total Medals
# Age               -0.072357
# Year               0.007095
# Gold Medals        0.399562
# Silver Medals      0.235226
# Bronze Medals      0.139893
# Total Medals       1.000000

# %% [markdown]
# # To print Random data

# %%
d.sample(8)
# Out:
#              Athlete   Age        Country  Year Closing Ceremony Date  \
# 3031   Nathan Wilmot  28.0      Australia  2008            2008-08-24
# 8600      Yun Mi-Jin  21.0    South Korea  2004            2004-08-29
# 131      Frode Estil  29.0         Norway  2002            2002-02-24
# 6617   Marit Bjørgen  25.0         Norway  2006            2006-02-26
# 1638      Zhang Ping  22.0          China  2004            2004-08-29
# 7000    Terry Tiffee  29.0  United States  2008            2008-08-24
# 7854       Zhang Jun  26.0          China  2004            2004-08-29
# 2602  Masumi Mishina  22.0          Japan  2004            2004-08-29
#
#                      Sport  Gold Medals  Silver Medals  Bronze Medals  \
# 3031               Sailing            1              0              0
# 8600               Archery            1              0              0
# 131   Cross Country Skiing            2              1              0
# ...

# %% [markdown]
# # To print different total medals of different countries

# %%
d1=d.copy()
d1=d1.pivot_table('Total Medals',columns='Country',aggfunc='sum')
d1
# Out:
# Country       Afghanistan  Algeria  Argentina  Armenia  Australia  Austria  \
# Total Medals            2        8        141       10        609       91
#
# Country       Azerbaijan  Bahamas  Bahrain  Barbados  ...  Turkey  Uganda  \
# Total Medals          25       24        1         1  ...      28       1
#
# Country       Ukraine  United Arab Emirates  United States  Uruguay  \
# Total Medals      143                     1           1312        1
#
# Country       Uzbekistan  Venezuela  Vietnam  Zimbabwe
# Total Medals          19          4        2         7
#
# [1 rows x 110 columns]

# %% [markdown]
# # To print different Gold medals of different countries

# %%
d2=d.copy()
d2=d2.pivot_table('Gold Medals',columns='Country',aggfunc='sum')
d2
# Out:
# Country      Afghanistan  Algeria  Argentina  Armenia  Australia  Austria  \
# Gold Medals            0        2         49        0        163       36
#
# Country      Azerbaijan  Bahamas  Bahrain  Barbados  ...  Turkey  Uganda  \
# Gold Medals           6       11        0         0  ...       9       1
#
# Country      Ukraine  United Arab Emirates  United States  Uruguay  \
# Gold Medals       31                     1            552        0
#
# Country      Uzbekistan  Venezuela  Vietnam  Zimbabwe
# Gold Medals           5          1        0         2
#
# [1 rows x 110 columns]

# %% [markdown]
# # To print different Silver medals of different countries

# %%
d3=d.copy()
d3=d3.pivot_table('Silver Medals',columns='Country',aggfunc='sum')
d3
# Out:
# Country        Afghanistan  Algeria  Argentina  Armenia  Australia  Austria  \
# Silver Medals            0        2         34        1        226       26
#
# Country        Azerbaijan  Bahamas  Bahrain  Barbados  ...  Turkey  Uganda  \
# Silver Medals           4        6        0         0  ...       9       0
#
# Country        Ukraine  United Arab Emirates  United States  Uruguay  \
# Silver Medals       38                     0            440        1
#
# Country        Uzbekistan  Venezuela  Vietnam  Zimbabwe
# Silver Medals           4          0        2         4
#
# [1 rows x 110 columns]

# %% [markdown]
# # To print different Bronze medals of different countries

# %%
d4=d.copy()
d4=d4.pivot_table('Bronze Medals',columns='Country',aggfunc='sum')
d4
# Out:
# Country        Afghanistan  Algeria  Argentina  Armenia  Australia  Austria  \
# Bronze Medals            2        4         58        9        220       29
#
# Country        Azerbaijan  Bahamas  Bahrain  Barbados  ...  Turkey  Uganda  \
# Bronze Medals          15        7        1         1  ...      10       0
#
# Country        Ukraine  United Arab Emirates  United States  Uruguay  \
# Bronze Medals       74                     0            320        0
#
# Country        Uzbekistan  Venezuela  Vietnam  Zimbabwe
# Bronze Medals          10          3        0         1
#
# [1 rows x 110 columns]

# %% [markdown]
# # Create a data frame basis Gold, Silver and Bronze Medals

# %%
d5=d.copy()
d5['Total Medals']=d['Gold Medals']+d['Bronze Medals']+d['Silver Medals']
d5=d5.groupby(['Country'])['Total Medals'].sum()
d5=pd.DataFrame(d5)
d5
# Out:
#              Total Medals
# Country
# Afghanistan             2
# Algeria                 8
# Argentina             141
# Armenia                10
# Australia             609
# ...                   ...
# Uruguay                 1
# Uzbekistan             19
# Venezuela               4
# Vietnam                 2
# Zimbabwe                7
#
# [110 rows x 1 columns]

# %% [markdown]
# # Print 10 head rows basis of new data frame

# %%
d5.head(10)
# Out:
#              Total Medals
# Country
# Afghanistan             2
# Algeria                 8
# Argentina             141
# Armenia                10
# Australia             609
# Austria                91
# Azerbaijan             25
# Bahamas                24
# Bahrain                 1
# Barbados                1

# %% [markdown]
# # Print 10 tail rows basis of new data frame

# %%
d5.tail(10)
# Out:
#                       Total Medals
# Country
# Turkey                          28
# Uganda                           1
# Ukraine                        143
# United Arab Emirates             1
# United States                 1312
# Uruguay                          1
# Uzbekistan                      19
# Venezuela                        4
# Vietnam                          2
# Zimbabwe                         7

# %% [markdown]
# # Print 10 head rows basis of data set

# %%
d.head(10)
# Out:
#             Athlete   Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
# 5     Alicia Coutts  24.0      Australia  2012            2012-08-12
# 6    Missy Franklin  17.0  United States  2012            2012-08-12
# 7       Ryan Lochte  27.0  United States  2012            2012-08-12
# 8   Allison Schmitt  22.0  United States  2012            2012-08-12
# 9  Natalie Coughlin  21.0  United States  2004            2004-08-29
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0    Swimming            8              0              0             8
# ...

# %% [markdown]
# # Print 10 tail rows basis of data set

# %%
d.tail(10)
# Out:
#                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 8608         Butch Johnson  45.0  United States  2000            2000-10-01
# 8609        Kim Cheong-Tae  20.0    South Korea  2000            2000-10-01
# 8610       Barbara Mensing  39.0        Germany  2000            2000-10-01
# 8611             O Gyo-Mun  28.0    South Korea  2000            2000-10-01
# 8612        Cornelia Pfohl  29.0        Germany  2000            2000-10-01
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # To check total medal in different year

# %%
pd.crosstab(d['Country'],d['Year'])
# Out:
# Year         2000  2002  2004  2006  2008  2010  2012
# Country
# Afghanistan     0     0     0     0     1     0     1
# Algeria         5     0     0     0     2     0     1
# Argentina      20     0    49     0    51     0    21
# Armenia         1     0     0     0     6     0     3
# Australia     161     2   133     2   124     3    99
# ...           ...   ...   ...   ...   ...   ...   ...
# Uruguay         1     0     0     0     0     0     0
# Uzbekistan      4     0     5     0     6     0     4
# Venezuela       0     0     2     0     1     0     1
# Vietnam         1     0     0     0     1     0     0
# Zimbabwe        0     0     1     0     1     0     0
#
# [110 rows x 7 columns]

# %% [markdown]
# # Sort values basis of year

# %%
d.sort_values(by="Year")
# Out:
#                   Athlete   Age        Country  Year Closing Ceremony Date  \
# 8617            Rod White  23.0  United States  2000            2000-10-01
# 6261  Aleksandr Dobroskok  18.0         Russia  2000            2000-10-01
# 2317        Sam Arsenault  18.0  United States  2000            2000-10-01
# 2318         Amanda Beard  18.0  United States  2000            2000-10-01
# 2319        B. J. Bedford  27.0  United States  2000            2000-10-01
# ...                   ...   ...            ...   ...                   ...
# 5452         Asuna Tanaka  24.0          Japan  2012            2012-08-12
# 5451        Megumi Takase  21.0          Japan  2012            2012-08-12
# 5450      Chelsea Stewart  22.0         Canada  2012            2012-08-12
# 1171        Heather Petri  34.0  United States  2012            2012-08-12
# 7190     Taras Shelestiuk  26.0        Ukraine  2012            2012-08-12
#
# ...

# %% [markdown]
# # Sort values basis of latest to old

# %%
d.sort_values(by="Year",ascending=False)
# Out:
#              Athlete   Age        Country  Year Closing Ceremony Date  \
# 2148     Haruka Ueda  24.0          Japan  2012            2012-08-12
# 5383   Hwang Seok-Ho  23.0    South Korea  2012            2012-08-12
# 5377     Robyn Gayle  26.0         Canada  2012            2012-08-12
# 5378   Gi Seong-Yong  23.0    South Korea  2012            2012-08-12
# 5379     Gu Ja-Cheol  23.0    South Korea  2012            2012-08-12
# ...              ...   ...            ...   ...                   ...
# 2322  Gustavo Borges  27.0         Brazil  2000            2000-10-01
# 2321       Kim Black  21.0  United States  2000            2000-10-01
# 2320   Lindsay Benko  23.0  United States  2000            2000-10-01
# 2319   B. J. Bedford  27.0  United States  2000            2000-10-01
# 8617       Rod White  23.0  United States  2000            2000-10-01
#
#          Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# ...

# %%
d.sort_values(by="Year",ascending=False)
# Out:
#              Athlete   Age        Country  Year Closing Ceremony Date  \
# 2148     Haruka Ueda  24.0          Japan  2012            2012-08-12
# 5383   Hwang Seok-Ho  23.0    South Korea  2012            2012-08-12
# 5377     Robyn Gayle  26.0         Canada  2012            2012-08-12
# 5378   Gi Seong-Yong  23.0    South Korea  2012            2012-08-12
# 5379     Gu Ja-Cheol  23.0    South Korea  2012            2012-08-12
# ...              ...   ...            ...   ...                   ...
# 2322  Gustavo Borges  27.0         Brazil  2000            2000-10-01
# 2321       Kim Black  21.0  United States  2000            2000-10-01
# 2320   Lindsay Benko  23.0  United States  2000            2000-10-01
# 2319   B. J. Bedford  27.0  United States  2000            2000-10-01
# 8617       Rod White  23.0  United States  2000            2000-10-01
#
#          Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # Drop column of closing ceremony

# %%
d= d.drop(["Closing Ceremony Date"],axis=1)

# %%
d
# Out:
#                    Athlete   Age        Country  Year       Sport  \
# 0           Michael Phelps  23.0  United States  2008    Swimming
# 1           Michael Phelps  19.0  United States  2004    Swimming
# 2           Michael Phelps  27.0  United States  2012    Swimming
# 3         Natalie Coughlin  25.0  United States  2008    Swimming
# 4            Aleksey Nemov  24.0         Russia  2000  Gymnastics
# ...                    ...   ...            ...   ...         ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000     Archery
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000     Archery
# 8615      Wietse van Alten  21.0    Netherlands  2000     Archery
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000     Archery
# 8617             Rod White  23.0  United States  2000     Archery
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0               8              0              0             8
# ...

# %% [markdown]
# # Query to extract data of the year 2012

# %%
d_2012 = d.loc[(d["Year"]==2012)]
d_2012
# Out:
#               Athlete   Age        Country  Year     Sport  Gold Medals  \
# 2      Michael Phelps  27.0  United States  2012  Swimming            4
# 5       Alicia Coutts  24.0      Australia  2012  Swimming            1
# 6      Missy Franklin  17.0  United States  2012  Swimming            4
# 7         Ryan Lochte  27.0  United States  2012  Swimming            2
# 8     Allison Schmitt  22.0  United States  2012  Swimming            3
# ...               ...   ...            ...   ...       ...          ...
# 8561    Lee Seong-Jin  27.0    South Korea  2012   Archery            1
# 8562    Mauro Nespoli  24.0          Italy  2012   Archery            1
# 8563       Aída Román  24.0         Mexico  2012   Archery            0
# 8564      Jacob Wukie  26.0  United States  2012   Archery            0
# 8565          Xu Jing  21.0          China  2012   Archery            0
#
#       Silver Medals  Bronze Medals  Total Medals
# 2                 2              0             6
# ...

# %% [markdown]
# # Calculating total Gold Medals of the 2012

# %%
t_Gcount = d_2012.loc[:,"Gold Medals"]
s_g = np.sum(t_Gcount)
s_g
# Out:
# 632

# %% [markdown]
# # Calculating total Silver Medals of the 2012

# %%
t_Scount = d_2012.loc[:,"Silver Medals"]
s_s = np.sum(t_Scount)
s_s
# Out:
# 634

# %% [markdown]
# # Calculating total Bronze Medals of the 2012

# %%
t_Bcount = d_2012.loc[:,"Bronze Medals"]
s_b = np.sum(t_Bcount)
s_b
# Out:
# 680

# %% [markdown]
# # Query to extract data of age 27 group 2012

# %%
d_age_2012 = d_2012.loc[(d_2012["Age"]==27)]
d_age_2012
# Out:
#                 Athlete   Age        Country  Year      Sport  Gold Medals  \
# 2        Michael Phelps  27.0  United States  2012   Swimming            4
# 7           Ryan Lochte  27.0  United States  2012   Swimming            2
# 39         Matt Grevers  27.0  United States  2012   Swimming            2
# 215        Aya Terakawa  27.0          Japan  2012   Swimming            0
# 339     Olena Kostevych  27.0        Ukraine  2012   Shooting            0
# ...                 ...   ...            ...   ...        ...          ...
# 8034   Anita Wlodarczyk  27.0         Poland  2012  Athletics            0
# 8548      Choi Hyeon-Ju  27.0    South Korea  2012    Archery            1
# 8553  Takaharu Furukawa  27.0          Japan  2012    Archery            0
# 8556      Im Dong-Hyeon  27.0    South Korea  2012    Archery            0
# 8561      Lee Seong-Jin  27.0    South Korea  2012    Archery            1
#
#       Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # Calculating total Gold Medals age 27 in 2012 year¶

# %%
t_age27_Gcount = d_2012.loc[:,"Gold Medals"]
s_age27_g = np.sum(t_age27_Gcount)
s_age27_g
# Out:
# 632

# %% [markdown]
# # Calculating total Silver Medals age 27 in 2012 year

# %%
t_age27_Scount = d_2012.loc[:,"Silver Medals"]
s_age27_s = np.sum(t_age27_Scount)
s_age27_s
# Out:
# 634

# %% [markdown]
# # Calculating total Bronze Medals age 27 in 2012 year

# %%
t_age27_Bcount = d_2012.loc[:,"Bronze Medals"]
s_age27_b = np.sum(t_age27_Bcount)
s_age27_b
# Out:
# 680

# %% [markdown]
# # Query to extract record of Russia

# %%
d_Russia = d.loc[(d["Country"]=="Russia")]
d_Russia
# Out:
#                    Athlete   Age Country  Year       Sport  Gold Medals  \
# 4            Aleksey Nemov  24.0  Russia  2000  Gymnastics            2
# 29         Aliya Mustafina  17.0  Russia  2012  Gymnastics            1
# 31           Dmitry Sautin  26.0  Russia  2000      Diving            1
# 120      Svetlana Khorkina  21.0  Russia  2000  Gymnastics            1
# 121   Yekaterina Lobaznyuk  17.0  Russia  2000  Gymnastics            0
# ...                    ...   ...     ...   ...         ...          ...
# 8478      Yuliya Sotnikova  29.0  Russia  2000   Athletics            0
# 8484        Maksim Tarasov  29.0  Russia  2000   Athletics            0
# 8503       Yelena Yelesina  30.0  Russia  2000   Athletics            1
# 8507         Olesya Zykina  19.0  Russia  2000   Athletics            0
# 8567         Bair Badyonov  32.0  Russia  2008     Archery            0
#
#       Silver Medals  Bronze Medals  Total Medals
# 4                 1              3             6
# ...

# %%
d_Russia.sort_values(by="Gold Medals",ascending = False)
# Out:
#                     Athlete   Age Country  Year                  Sport  \
# 4             Aleksey Nemov  24.0  Russia  2000             Gymnastics
# 183      Svetlana Romashina  22.0  Russia  2012  Synchronized Swimming
# 601    Svetlana Ishmuratova  33.0  Russia  2006               Biathlon
# 195        Mariya Kiselyova  25.0  Russia  2000  Synchronized Swimming
# 193    Anastasiya Yermakova  21.0  Russia  2004  Synchronized Swimming
# ...                     ...   ...     ...   ...                    ...
# 3853       Albert Demchenko  34.0  Russia  2006                   Luge
# 1025        Oksana Slivenko  21.0  Russia  2008          Weightlifting
# 1029  Nadezhda Yevstyukhina  20.0  Russia  2008          Weightlifting
# 1032   Khadzhimurat Akkayev  19.0  Russia  2004          Weightlifting
# 8567          Bair Badyonov  32.0  Russia  2008                Archery
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # Extract Sport Gymnastics of Russia

# %%
d_gym_russ = d_Russia.loc[(d_Russia["Sport"]=="Gymnastics")]
d_gym_russ
# Out:
#                           Athlete   Age Country  Year       Sport  \
# 4                   Aleksey Nemov  24.0  Russia  2000  Gymnastics
# 29                Aliya Mustafina  17.0  Russia  2012  Gymnastics
# 120             Svetlana Khorkina  21.0  Russia  2000  Gymnastics
# 121          Yekaterina Lobaznyuk  17.0  Russia  2000  Gymnastics
# 122         Yelena Zamolodchikova  17.0  Russia  2000  Gymnastics
# 362                Denis Ablyazin  19.0  Russia  2012  Gymnastics
# 367              Viktoriya Komova  17.0  Russia  2012  Gymnastics
# 370                 Mariya Paseka  17.0  Russia  2012  Gymnastics
# 375            Anton Golotsutskov  23.0  Russia  2008  Gymnastics
# 386             Svetlana Khorkina  25.0  Russia  2004  Gymnastics
# 388                  Anna Pavlova  16.0  Russia  2004  Gymnastics
# 396            Aleksey Bondarenko  22.0  Russia  2000  Gymnastics
# 401              Yelena Produnova  20.0  Russia  2000  Gymnastics
# ...

# %% [markdown]
# # list Sport category of Russia

# %%
l_russ_spt = list(d_Russia.loc[:,"Sport"].unique())
l_russ_spt.sort()
print(l_russ_spt,end=" ")
# Out:
# ['Archery', 'Athletics', 'Badminton', 'Basketball', 'Biathlon', 'Bobsleigh', 'Boxing', 'Canoeing', 'Cross Country Skiing', 'Cycling', 'Diving', 'Fencing', 'Figure Skating', 'Freestyle Skiing', 'Gymnastics', 'Handball', 'Ice Hockey', 'Judo', 'Luge', 'Modern Pentathlon', 'Rhythmic Gymnastics', 'Rowing', 'Shooting', 'Skeleton', 'Snowboarding', 'Speed Skating', 'Swimming', 'Synchronized Swimming', 'Taekwondo', 'Tennis', 'Trampoline', 'Volleyball', 'Waterpolo', 'Weightlifting', 'Wrestling']

# %% [markdown]
# # Create a data frame of Sport Badminton of Russia

# %%
d_Badm_russ = pd.DataFrame(d_gym_russ)
d_Badm_russ
# Out:
#                           Athlete   Age Country  Year       Sport  \
# 4                   Aleksey Nemov  24.0  Russia  2000  Gymnastics
# 29                Aliya Mustafina  17.0  Russia  2012  Gymnastics
# 120             Svetlana Khorkina  21.0  Russia  2000  Gymnastics
# 121          Yekaterina Lobaznyuk  17.0  Russia  2000  Gymnastics
# 122         Yelena Zamolodchikova  17.0  Russia  2000  Gymnastics
# 362                Denis Ablyazin  19.0  Russia  2012  Gymnastics
# 367              Viktoriya Komova  17.0  Russia  2012  Gymnastics
# 370                 Mariya Paseka  17.0  Russia  2012  Gymnastics
# 375            Anton Golotsutskov  23.0  Russia  2008  Gymnastics
# 386             Svetlana Khorkina  25.0  Russia  2004  Gymnastics
# 388                  Anna Pavlova  16.0  Russia  2004  Gymnastics
# 396            Aleksey Bondarenko  22.0  Russia  2000  Gymnastics
# 401              Yelena Produnova  20.0  Russia  2000  Gymnastics
# ...

# %% [markdown]
# # To show data from country Russia

# %%
d_Russia_G = d_Russia.sort_values(by="Gold Medals",ascending=False)

# %%
d_Russia_G
# Out:
#                     Athlete   Age Country  Year                  Sport  \
# 4             Aleksey Nemov  24.0  Russia  2000             Gymnastics
# 183      Svetlana Romashina  22.0  Russia  2012  Synchronized Swimming
# 601    Svetlana Ishmuratova  33.0  Russia  2006               Biathlon
# 195        Mariya Kiselyova  25.0  Russia  2000  Synchronized Swimming
# 193    Anastasiya Yermakova  21.0  Russia  2004  Synchronized Swimming
# ...                     ...   ...     ...   ...                    ...
# 3853       Albert Demchenko  34.0  Russia  2006                   Luge
# 1025        Oksana Slivenko  21.0  Russia  2008          Weightlifting
# 1029  Nadezhda Yevstyukhina  20.0  Russia  2008          Weightlifting
# 1032   Khadzhimurat Akkayev  19.0  Russia  2004          Weightlifting
# 8567          Bair Badyonov  32.0  Russia  2008                Archery
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # To show data set of India

# %%
d_India = d.loc[(d["Country"]=="India")]
d_India
# Out:
#                    Athlete   Age Country  Year          Sport  Gold Medals  \
# 702         Yogeshwar Dutt  29.0   India  2012      Wrestling            0
# 722           Sushil Kumar  29.0   India  2012      Wrestling            0
# 797           Sushil Kumar  25.0   India  2008      Wrestling            0
# 1094     Karnam Malleswari  25.0   India  2000  Weightlifting            0
# 2786           Vijay Kumar  26.0   India  2012       Shooting            0
# 2791          Gagan Narang  29.0   India  2012       Shooting            0
# 2807        Abhinav Bindra  25.0   India  2008       Shooting            1
# 2877  Rajyavardhan Rathore  34.0   India  2004       Shooting            0
# 7170        M. C. Mary Kom  29.0   India  2012         Boxing            0
# 7235        Vijender Singh  22.0   India  2008         Boxing            0
# 7806          Saina Nehwal  22.0   India  2012      Badminton            0
#
#       Silver Medals  Bronze Medals  Total Medals
# ...

# %% [markdown]
# # Extract query sport category shooting in india

# %%
d_shoot_india = d_India.loc[(d_India["Sport"]=="Shooting")]
d_shoot_india
# Out:
#                    Athlete   Age Country  Year     Sport  Gold Medals  \
# 2786           Vijay Kumar  26.0   India  2012  Shooting            0
# 2791          Gagan Narang  29.0   India  2012  Shooting            0
# 2807        Abhinav Bindra  25.0   India  2008  Shooting            1
# 2877  Rajyavardhan Rathore  34.0   India  2004  Shooting            0
#
#       Silver Medals  Bronze Medals  Total Medals
# 2786              1              0             1
# 2791              0              1             1
# 2807              0              0             1
# 2877              1              0             1

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Total Medal Basis of year

# %%
plt.bar(d['Year'],d['Total Medals'])
plt.title('Year Vs Total Medals',fontsize=15,color='red')
plt.xlabel('Year',fontsize=15,color='green')
plt.ylabel('Total Medals',fontsize=15,color='green')
plt.grid(True)
plt.show()

# %% [markdown]
# # Medals Range in different years

# %%
d.groupby('Year')[['Gold Medals','Silver Medals','Bronze Medals']].sum().plot.bar(color=['gold','silver','brown']
                                                                                          ,figsize=(15,10))
plt.title("Year wise different Medals Range",color="Green",fontsize=25)
plt.ylabel('Total Medals')
plt.show()

# %% [markdown]
# # To plot Medals Category Of India

# %%
d_India.groupby('Year')[['Gold Medals','Silver Medals','Bronze Medals']].sum().plot.bar(color=['gold','silver','brown']
                                                                                        ,figsize=(15,10))
plt.title("Total Medals in India",Color="green",fontsize=25)
plt.ylabel('Total Medals')
plt.show()

# %% [markdown]
# # To show plot different Medals of Russia

# %%
plt.bar(d_Russia['Year'],d_Russia["Gold Medals"],color="red")
plt.title("Russia Gold Medals",fontsize=15,color='green')
plt.xlabel('Year',fontsize=15,color="blue")
plt.ylabel('Gold Medals',fontsize=15,color="blue")
plt.grid(True)
plt.show()

# %%
plt.bar(d_Russia['Year'],d_Russia["Silver Medals"],color="red")
plt.title("Russia Silver Medals",fontsize=15,color='green')
plt.xlabel('Year',fontsize=15,color="blue")
plt.ylabel('Silver Medals',fontsize=15,color="blue")
plt.grid(True)
plt.show()

# %%
plt.bar(d_Russia_G['Year'],d_Russia_G["Bronze Medals"],color="red")
plt.title("Russia Bronze Medals",fontsize=15,color='green')
plt.xlabel('Year',fontsize=15,color="blue")
plt.ylabel('Bronze Medals',fontsize=15,color="blue")
plt.grid(True)
plt.show()

# %% [markdown]
# # Gold medals of Russia basis of year and age

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='Year',y="Gold Medals",hue='Age',data=d_Russia)
plt.show()

# %% [markdown]
# # Gold Medals basis of age from dataset

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='Year',y="Gold Medals",hue='Age',data=d)
plt.show()

# %% [markdown]
# # Silver Medals basis of age

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='Year',y="Silver Medals",hue='Age',data=d)
plt.show()

# %% [markdown]
# # Medals Category of Russia

# %%
d_Russia.groupby('Year')[['Gold Medals','Silver Medals','Bronze Medals']].sum().plot.bar(color=['gold','silver','brown']
                                                                                          ,figsize=(15,10))
plt.title("Year wise different Medals Range of Russia",color="Green",fontsize=25)
plt.ylabel('Total Medals')
plt.show()

# %% [markdown]
# # Bronze Medals basis of age

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='Year',y="Bronze Medals",hue='Age',data=d)
plt.show()

# %% [markdown]
# # Sport Gymnastics medals of Russia basis of year

# %%
sns.countplot(x="Year",data=d_gym_russ,palette='tab10')
plt.show()

# %% [markdown]
# # India shooting medals

# %%
sns.countplot(x="Year",data=d_shoot_india,palette='tab10')
plt.show()

# %% [markdown]
# # Analysis of sample data using graph

# %%
d_samp = d.sample(10)

# %%
d_samp
# Out:
#                    Athlete   Age      Country  Year     Sport  Gold Medals  \
# 7038         Daisuke Miura  30.0        Japan  2004  Baseball            0
# 1976         Daniel Nestor  28.0       Canada  2000    Tennis            1
# 356           Eeke van Nes  31.0  Netherlands  2000    Rowing            0
# 5750     Kerstin Stegemann  22.0      Germany  2000  Football            0
# 4705            Rob Derikx  21.0  Netherlands  2004    Hockey            0
# 604           Sven Fischer  30.0      Germany  2002  Biathlon            0
# 3479             Drew Ginn  29.0    Australia  2004    Rowing            1
# 4636               Ma Yibo  28.0        China  2008    Hockey            0
# 3369     Dorian Mortelette  24.0       France  2008    Rowing            0
# 3551  Kirsten van der Kolk  28.0  Netherlands  2004    Rowing            0
#
#       Silver Medals  Bronze Medals  Total Medals
# 7038              0              1             1
# ...

# %% [markdown]
# # Gold medals basis of Country from Sample data set

# %%
sns.set_style("darkgrid")
sns.stripplot(x="Country",y='Gold Medals',data=d_samp)
plt.show()

# %% [markdown]
# # Total medals range basis of countries

# %%
sns.set_style("darkgrid")
sns.stripplot(x="Year",y='Total Medals',hue="Country",jitter=0.60,data=d_samp)
plt.show()

# %% [markdown]
# # To plot Silver Medals basis of Year and Age

# %%
sns.lineplot(x="Year",y='Age',hue='Silver Medals',data=d)
plt.show()

# %% [markdown]
# # To show probability density of Bronze Medals

# %%
sns.kdeplot(d['Bronze Medals'])
plt.show()

# %%
sns.kdeplot(d['Bronze Medals'],color='yellow',shade=True)
plt.show()

# %% [markdown]
# # To show probabilty density of Silver medals

# %%
sns.kdeplot(d['Silver Medals'],d['Total Medals'],color='green',shade=True)
plt.show()

# %% [markdown]
# # To show plot wise relationsip of all data set

# %%
sns.pairplot(d)
plt.show()

# %%
sns.pairplot(d,diag_kind="kde")
plt.show()

# %% [markdown]
# # To show Gold Medal relationship from dataset

# %%
sns.pairplot(d,diag_kind="kde",hue='Gold Medals')
plt.show()

# %% [markdown]
# # To show diagonal relationship of dataset

# %%
sns.pairplot(d,diag_kind="hist",kind='reg')
plt.show()

# %% [markdown]
# # To show relatioship of Gold,Silver and Bronze Medals basis of Age

# %%
sns.pairplot(d[d.Age.isin([12,18,21,27,30,40])],
            hue='Age',
            vars=['Gold Medals','Silver Medals','Bronze Medals'],
            palette='inferno_r')

# %% [markdown]
# # Visualize distribution of age from data set

# %%
sns.violinplot(x=d.Age)
plt.show()

# %% [markdown]
# # To show data distribution basis of Year and Age

# %%
sns.violinplot(x='Year',y='Age',data=d)
plt.show()

# %% [markdown]
# # Gold Medals distribution basis of Year and Age

# %%
sns.violinplot(x='Year',y='Age',hue='Gold Medals',data=d)
plt.show()

# %% [markdown]
# # To show Distribution of Japan basis of Age and Year

# %%
Japan = d[d.Country == 'Japan']
sns.violinplot(x=Japan.Year,y=Japan.Age,color = 'xkcd:forest green')
plt.show()

# %% [markdown]
# # To show Distribution of Russia basis of Age and Year

# %%
Russia = d[d.Country == 'Russia']
sns.violinplot(x=Russia.Year,y=Russia.Age,color = 'xkcd:forest green')
plt.show()

# %% [markdown]
# # Data visualization of all data set in different ways

# %%
sns.heatmap(d.corr())
plt.show()

# %%
sns.heatmap(d.corr(),cmap='RdBu',vmin=-1,vmax=1)
plt.show()

# %%
sns.heatmap(d.corr(),cmap='RdBu',vmin=-0,vmax=1)
plt.show()

# %%
sns.heatmap(d.corr(),cmap='RdBu',annot= True)
plt.show()

# %%
sns.heatmap(d.corr(),cmap='RdBu',annot=True,fmt='.1f')
plt.show()

# %% [markdown]
# # Age group distribution from data set

# %%
sns.distplot(d.Age)
plt.show()

# %%
sns.distplot(d.Age,bins=10)

plt.show()

# %% [markdown]
# # To show relationship of sample data set

# %%
sns.pairplot(d_samp)
plt.show()

# %%
sns.pairplot(d_samp,diag_kind="kde")
plt.show()

# %% [markdown]
# # To show Gold Medal relationship from Sample Data

# %%
sns.pairplot(d_samp,diag_kind="kde",hue='Gold Medals')
plt.show()

# %%
sns.pairplot(d_samp,diag_kind="hist",kind='reg')
plt.show()
